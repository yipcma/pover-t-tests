# %%
import numpy as np
from catboost import CatBoostClassifier
# initialize data
train_data = np.random.randint(0, 100, size=(100, 10))
train_label = np.random.randint(0, 2, size=(100))
test_data = np.random.randint(0, 100, size=(50, 10))
# specify the training parameters 
model = CatBoostClassifier(iterations=1000, depth=2, learning_rate=1, loss_function='Logloss', logging_level='Verbose')
#train the model
model.fit(train_data, train_label, cat_features=[0,2,5])
# make the prediction using the resulting model
preds_class = model.predict(test_data)
preds_proba = model.predict_proba(test_data)
# print("class = ", preds_class)
# print("proba = ", preds_proba)
# Out:
# 0:	learn: 0.6547546	total: 96ms	remaining: 1m 35s
# 1:	learn: 0.6462472	total: 142ms	remaining: 1m 10s
# 2:	learn: 0.6283139	total: 221ms	remaining: 1m 13s
# 3:	learn: 0.5861813	total: 277ms	remaining: 1m 8s
# 4:	learn: 0.5391978	total: 324ms	remaining: 1m 4s
# 5:	learn: 0.5271676	total: 369ms	remaining: 1m 1s
# 6:	learn: 0.5166327	total: 427ms	remaining: 1m
# 7:	learn: 0.5129573	total: 442ms	remaining: 54.8s
# 8:	learn: 0.4680719	total: 489ms	remaining: 53.9s
# 9:	learn: 0.4436843	total: 508ms	remaining: 50.3s
# 10:	learn: 0.4262781	total: 523ms	remaining: 47s
# 11:	learn: 0.4121308	total: 541ms	remaining: 44.5s
# 12:	learn: 0.4010824	total: 556ms	remaining: 42.2s
# 13:	learn: 0.3843809	total: 569ms	remaining: 40.1s
# 14:	learn: 0.3613078	total: 591ms	remaining: 38.8s
# 15:	learn: 0.3354777	total: 604ms	remaining: 37.2s
# 16:	learn: 0.3159265	total: 637ms	remaining: 36.9s
# 17:	learn: 0.2939665	total: 655ms	remaining: 35.7s
# 18:	learn: 0.2938335	total: 664ms	remaining: 34.3s
# ...

# %%
import numpy as np
from catboost import CatBoostClassifier
# initialize data
train_data = np.random.randint(0, 100, size=(100, 10))
train_label = np.random.randint(0, 2, size=(100))
test_data = np.random.randint(0, 100, size=(50, 10))
# specify the training parameters 
model = CatBoostClassifier(task_type='GPU', iterations=1000, depth=2, learning_rate=1, loss_function='Logloss', logging_level='Verbose')
#train the model
model.fit(train_data, train_label, cat_features=[0,2,5])
# make the prediction using the resulting model
preds_class = model.predict(test_data)
preds_proba = model.predict_proba(test_data)
# print("class = ", preds_class)
# print("proba = ", preds_proba)
# Out:
# 0:	learn: 0.6095750809	total: 34.1ms	remaining: 34.1s
# 1:	learn: 0.5535736847	total: 66ms	remaining: 33s
# 2:	learn: 0.5147440338	total: 94.2ms	remaining: 31.3s
# 3:	learn: 0.490022583	total: 121ms	remaining: 30.2s
# 4:	learn: 0.4832089233	total: 150ms	remaining: 29.9s
# 5:	learn: 0.4376334	total: 178ms	remaining: 29.5s
# 6:	learn: 0.4116308594	total: 204ms	remaining: 29s
# 7:	learn: 0.4016598129	total: 230ms	remaining: 28.5s
# 8:	learn: 0.3906125641	total: 256ms	remaining: 28.2s
# 9:	learn: 0.3830393219	total: 283ms	remaining: 28s
# 10:	learn: 0.3828066254	total: 309ms	remaining: 27.8s
# 11:	learn: 0.3718561554	total: 334ms	remaining: 27.5s
# 12:	learn: 0.3407653046	total: 361ms	remaining: 27.4s
# 13:	learn: 0.2990642548	total: 387ms	remaining: 27.3s
# 14:	learn: 0.2923830605	total: 414ms	remaining: 27.2s
# 15:	learn: 0.2839781189	total: 439ms	remaining: 27s
# 16:	learn: 0.2258286858	total: 465ms	remaining: 26.9s
# 17:	learn: 0.2116780853	total: 492ms	remaining: 26.8s
# ...
